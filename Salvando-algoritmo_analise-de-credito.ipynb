# %%
import pandas as pd

# %%
# Importando database
base = pd.read_csv('credit_data.csv')

# %%
# Estatísticas do database
base.describe()
# Out:
#         i#clientid        income          age          loan    c#default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %%
# Amostra dos dados
base.head()
# Out:
#    i#clientid        income        age         loan  c#default
# 0           1  66155.925095  59.017015  8106.532131          0
# 1           2  34415.153966  48.117153  6564.745018          0
# 2           3  57317.170063  63.108049  8020.953296          0
# 3           4  42709.534201  45.751972  6103.642260          0
# 4           5  66952.688845  18.584336  8770.099235          1

# %%
# Verificando dados com idade negativa
base.loc[base['age'] < 0]
# Out:
#     i#clientid        income        age         loan  c#default
# 15          16  50501.726689 -28.218361  3977.287432          0
# 21          22  32197.620701 -52.423280  4244.057136          0
# 26          27  63287.038908 -36.496976  9595.286289          0

# %%
### Maneiras de contornar o problema das idades menores que zero

## 1) Apagar a coluna por inteiro (não recomendada, neste caso)
# base.drop('age', 1, inplace=True)

## 2) Apagar apenas os registros, por completo, que possuem essa incoerência
# base.drop(base[base.age < 0].index, inplace=True)

## 3) Preencher os valores com a média da coluna, apenas dos valores maiores que zero
media = base['age'][base.age > 0].mean()
base.loc[base.age < 0, 'age'] = media

# %%
# Verificando valores nulos
base.loc[pd.isnull(base['age'])]
# Out:
#     i#clientid        income  age         loan  c#default
# 28          29  59417.805406  NaN  2082.625938          0
# 30          31  48528.852796  NaN  6155.784670          0
# 31          32  23526.302555  NaN  2862.010139          0

# %%
# Divisão do dataset entre variáveis preditoras e target
previsores = base.iloc[:, 1:4].values
classe = base.iloc[:, 4].values

# %%
# Substituindo os valores missing pela média de cada coluna
from sklearn.preprocessing import Imputer

imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
imputer.fit(previsores[:, 0:3])

previsores[:, 0:3] = imputer.transform(previsores[:, 0:3])

# %%
## Fazendo o escalonamento (normalização) dos atributos
from sklearn.preprocessing import StandardScaler

# Padronização
scaler = StandardScaler()
previsores = scaler.fit_transform(previsores)

# Normalização
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# previsores = scaler.fit_transform(previsores)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
# Out:
# C:\Users\ricar\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# modelo SVM
classificadorSVM = SVC(kernel='rbf', C=2.0)
classificadorSVM.fit(previsores, classe)
# Out:
# SVC(C=2.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# modelo Random Forest
classificadorRandomForest = RandomForestClassifier(n_estimators=40, criterion='entropy')
classificadorRandomForest.fit(previsores, classe)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# modelo Redes Neurais
classificadorMLP = MLPClassifier(verbose=True, max_iter=500, tol=0.00001, solver='adam', hidden_layer_sizes=(100),
                                activation='relu', batch_size=200, learning_rate_init=0.001)
classificadorMLP.fit(previsores, classe)
# Out:
# Iteration 1, loss = 0.72035849
# Iteration 2, loss = 0.63602671
# Iteration 3, loss = 0.56394337
# Iteration 4, loss = 0.50313629
# Iteration 5, loss = 0.45188175
# Iteration 6, loss = 0.40813349
# Iteration 7, loss = 0.37093489
# Iteration 8, loss = 0.33856815
# Iteration 198, loss = 0.02486584
# Iteration 199, loss = 0.02474038
# Iteration 200, loss = 0.02467194
# Iteration 201, loss = 0.02457323
# Iteration 202, loss = 0.02440083
# Iteration 203, loss = 0.02425894
# Iteration 204, loss = 0.02421103
# Iteration 205, loss = 0.02407748
# Iteration 206, loss = 0.02389384
# Iteration 207, loss = 0.02389825
# Iteration 208, loss = 0.02372881
# Iteration 209, loss = 0.02369448
# Iteration 210, loss = 0.02357520
# Iteration 211, loss = 0.02347853
# Iteration 212, loss = 0.02331720
# Iteration 213, loss = 0.02334225
# Iteration 214, loss = 0.02322085
# Iteration 215, loss = 0.02327589
# Iteration 216, loss = 0.02309601
# Iteration 217, loss = 0.02286983
# Iteration 218, loss = 0.02271541
# Iteration 219, loss = 0.02277848
# Iteration 220, loss = 0.02251887
# Iteration 221, loss = 0.02241545
# Iteration 222, loss = 0.02233471
# Iteration 223, loss = 0.02227061
# Iteration 224, loss = 0.02217662
# Iteration 225, loss = 0.02207555
# Iteration 226, loss = 0.02202673
# Iteration 227, loss = 0.02197098
# Iteration 228, loss = 0.02190386
# Iteration 229, loss = 0.02173367
# Iteration 230, loss = 0.02162244
# Iteration 231, loss = 0.02158633
# Iteration 232, loss = 0.02147234
# Iteration 233, loss = 0.02137392
# Iteration 234, loss = 0.02130391
# Iteration 235, loss = 0.02128393
# Iteration 236, loss = 0.02113600
# Iteration 237, loss = 0.02112080
# Iteration 238, loss = 0.02094524
# Iteration 239, loss = 0.02085539
# Iteration 240, loss = 0.02080105
# Iteration 241, loss = 0.02080221
# Iteration 242, loss = 0.02062853
# Iteration 243, loss = 0.02054809
# Iteration 244, loss = 0.02048737
# Iteration 245, loss = 0.02038957
# Iteration 246, loss = 0.02034955
# Iteration 247, loss = 0.02020842
# Iteration 248, loss = 0.02015258
# Iteration 249, loss = 0.02008689
# Iteration 250, loss = 0.02014410
# Iteration 251, loss = 0.01996824
# Iteration 252, loss = 0.01993624
# Iteration 253, loss = 0.01977311
# Iteration 254, loss = 0.01968175
# Iteration 255, loss = 0.01968563
# Iteration 256, loss = 0.01960087
# Iteration 257, loss = 0.01949889
# Iteration 258, loss = 0.01937381
# Iteration 259, loss = 0.01932768
# Iteration 260, loss = 0.01933091
# Iteration 261, loss = 0.01921049
# Iteration 262, loss = 0.01915991
# Iteration 263, loss = 0.01913728
# Iteration 264, loss = 0.01910620
# Iteration 265, loss = 0.01892180
# Iteration 266, loss = 0.01888669
# Iteration 267, loss = 0.01881706
# Iteration 268, loss = 0.01875969
# Iteration 269, loss = 0.01864634
# Iteration 270, loss = 0.01866750
# Iteration 271, loss = 0.01857147
# Iteration 272, loss = 0.01848208
# Iteration 273, loss = 0.01837847
# Iteration 274, loss = 0.01838340
# Iteration 275, loss = 0.01839270
# Iteration 276, loss = 0.01838769
# Training loss did not improve more than tol=0.000010 for two consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size=200, beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=100, learning_rate='constant',
#        learning_rate_init=0.001, max_iter=500, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=1e-05, validation_fraction=0.1,
#        verbose=True, warm_start=False)

# %%
# Salvando modelos já treinados para aplicações comerciais
import pickle

# %%
pickle.dump(classificadorSVM, open('svm_finalizado.sav', 'wb'))

# %%
pickle.dump(classificadorRandomForest, open('random_forest_finalizado.sav', 'wb'))

# %%
pickle.dump(classificadorMLP, open('mlp_finalizado.sav', 'wb'))
